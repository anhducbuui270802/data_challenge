# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/pRoBERTa
# Out:
# /content/drive/.shortcut-targets-by-id/1LF-WP2ZCgIIdJNo5hvCwikjO_3USvDrU/pRoBERTa

# %%
# !wget https://public.vinai.io/PhoBERT_large_transformers.tar.gz
# !tar -xzvf PhoBERT_large_transformers.tar.gz
# Out:
# --2023-10-09 04:03:54--  https://public.vinai.io/PhoBERT_large_transformers.tar.gz
# Resolving public.vinai.io (public.vinai.io)... 13.35.166.24, 13.35.166.17, 13.35.166.106, ...
# Connecting to public.vinai.io (public.vinai.io)|13.35.166.24|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 874534298 (834M) [application/x-tar]
# Saving to: ‘PhoBERT_large_transformers.tar.gz’
#
# PhoBERT_large_trans 100%[===================>] 834.02M  50.3MB/s    in 17s
#
# 2023-10-09 04:04:11 (49.7 MB/s) - ‘PhoBERT_large_transformers.tar.gz’ saved [874534298/874534298]
#
# PhoBERT_large_transformers/
# PhoBERT_large_transformers/config.json
# PhoBERT_large_transformers/bpe.codes
# PhoBERT_large_transformers/model.bin
# PhoBERT_large_transformers/dict.txt

# %%
# !wget https://public.vinai.io/PhoBERT_base_transformers.tar.gz
# !tar -xzvf PhoBERT_base_transformers.tar.gz
# Out:
# --2023-10-09 13:12:01--  https://public.vinai.io/PhoBERT_base_transformers.tar.gz
# Resolving public.vinai.io (public.vinai.io)... 18.155.173.109, 18.155.173.107, 18.155.173.71, ...
# Connecting to public.vinai.io (public.vinai.io)|18.155.173.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 322405979 (307M) [application/x-tar]
# Saving to: ‘PhoBERT_base_transformers.tar.gz’
#
# PhoBERT_base_transf 100%[===================>] 307.47M  42.3MB/s    in 6.3s
#
# 2023-10-09 13:12:08 (48.6 MB/s) - ‘PhoBERT_base_transformers.tar.gz’ saved [322405979/322405979]
#
# PhoBERT_base_transformers/
# PhoBERT_base_transformers/config.json
# PhoBERT_base_transformers/bpe.codes
# PhoBERT_base_transformers/model.bin
# PhoBERT_base_transformers/dict.txt

# %%
data_path = "/content/drive/MyDrive/public_result.json"

# %%
import json

# Đọc dữ liệu từ file JSON
with open(data_path) as file:
    data = json.load(file)

# Tạo một từ điển để lưu trữ dữ liệu đã chuyển đổi
load_data = {}

# Lặp qua mỗi ID trong data
for id, item in data.items():
    data = {}
    data["verdict"] = item['verdict']
    data["evidence"] = item["evidence"]
    load_data[id] = data

# %%
load_data
# Out:
# {'29706': {'verdict': 'NEI', 'evidence': ''},
#  '32454': {'verdict': 'SUPPORTED',
#   'evidence': 'Tuy nhiên, MBA tập trung vào kỹ năng kinh doanh và quản lý.'},
#  '41947': {'verdict': 'SUPPORTED',
#   'evidence': 'Trong khi tranh cãi còn chưa dứt về số tài liệu mật được Cục Điều tra Liên bang Mỹ (FBI) thu hồi từ dinh thự Mar-a-Lago của cựu tổng thống Donald Trump hồi năm ngoái, chính trường Mỹ tuần này lại một lần nữa xôn xao về những tài liệu đóng dấu mật không được bảo quản đúng nơi quy định'},
#  '47909': {'verdict': 'SUPPORTED',
#   'evidence': 'Tiệm há cảo của anh Hùng có 8 vị nhân, được làm từ nhiều nguyên liệu khác nhau như mực, thịt bắp, gà lá chanh, thanh cua, thịt bò, thịt hẹ, xíu mại trứng cút, tôm thịt.'},
#  '46798': {'verdict': 'REFUTED',
#   'evidence': 'Đầm sen công viên thực vật cảnh Việt Nam Cách trung tâm Thủ đô chừng 10km, công viên Thực vật cảnh Việt Nam là nơi sở hữu hơn 2 nghìn loài hoa và các gốc thực vật khác nhau.'},
#  '47255': {'verdict': 'REFUTED',
# ...

# %%
import os
import json

def save_result(PATH, result_dict):
    # Tạo thư mục nếu nó chưa tồn tại
    os.makedirs(PATH, exist_ok=True)
    # Lưu từ điển vào tệp JSON
    result_path = os.path.join(PATH, "result_bao_gui.json")

    with open(result_path, "w", encoding="utf-8") as file:
        json.dump(load_data, file, ensure_ascii=False)

# %%
save_path = "/content/drive/MyDrive"
save_result(save_path, load_data)

# %%
! pip install pytorch_lightning
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 774.6/774.6 kB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 805.2/805.2 kB 57.8 MB/s eta 0:00:00
# ...

# %%
from pytorch_lightning import Trainer

# %%
Trainer.from_argparse_args()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-7059e31c6604> in <cell line: 1>()
# ----> 1 Trainer.from_argparse_args()
#
# AttributeError: type object 'Trainer' has no attribute 'from_argparse_args'
